# %%
#pip install fg-data-profiling

# %%
import pandas as pd
from data_profiling import ProfileReport
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("global_pharmacy_sales_2020_2025_daily_dataset.csv")

# %%
#basic chacks of data 
display(df.head())
print("Dataset Shape:", df.shape)
print("\nColumn Names:")
print(df.columns)
print("\nData Information:")
df.info()
# Out:
#          date  year  month  day         region    country category  \
# 0  2025-10-12  2025     10   12    Middle East        UAE  Chronic
# 1  2020-09-15  2020      9   15     South Asia      India  Chronic
# 2  2020-02-26  2020      2   26    Middle East        UAE  Vitamin
# 3  2025-11-09  2025     11    9     South Asia  Sri Lanka  Chronic
# 4  2022-04-04  2022      4    4  South America  Argentina  Chronic
#
#      medicine age_group  units_sold  unit_price  stock_level  \
# 0  Amlodipine      0-12         328       45.38         4774
# 1  Amlodipine     26-45         371       75.49         4584
# 2   Vitamin C      0-12         948       22.51         3934
# 3  Amlodipine      0-12         275       63.29         4544
# 4  Amlodipine     26-45         563       44.28         4284
#
#    expiry_days_remaining  covid_flag
# 0                    466           0
# 1                    181           1
# 2                    556           1
# 3                    330           0
# ...

# %%
# Create the automated EDA report
profile = ProfileReport(
    df,
    title="Global pharmacy sales - complete EDA report",
    explorative=True
)
# Show the report
profile
# Out:
# ...
# Render HTML:   0%|          | 0/1 [00:00<?, ?it/s]
# <iframe width="100%" height="800px" srcdoc="&lt;!doctype html&gt;&lt;html lang=en&gt;&lt;meta charset=utf-8&gt;&lt;meta content=&quot;width=device-width,initial-scale=1,shrink-to-fit=no&quot; name=viewport&gt;&lt;meta content=&quot;Profile report generated by YData! Visit us at https://ydata.ai&quot; name=description&gt;&lt;meta content=&quot;YData and the open source community.&quot; name=author&gt;&lt;meta content=&quot;YData Profiling v4.19.1&quot; name=generator&gt;&lt;meta content=https://github.com/Data-Centric-AI-Community/data-profiling name=url&gt;&lt;meta content=&quot;2026-08-23 12:17:54.667056&quot; name=date&gt;&lt;title&gt;Global pharmacy sales - complete EDA report&lt;/title&gt;&lt;style&gt;@charset &quot;UTF-8&quot;;/*!
#  * Bootstrap  v5.3.3 (https://getbootstrap.com/)
#  * Copyright 2011-2024 The Bootstrap Authors
#  * Licensed under MIT (https://github.com/twbs/bootstrap/blob/main/LICENSE)
# ...

# %%
# save this report as html 
#which can be opened in a web browser and shared with   stakeholders
profile.to_file("Global_Pharmacy_Sales_EDA_Report.html")
# Out:
# Export report to file:   0%|          | 0/1 [00:00<?, ?it/s]

# %%
# also using Sweetviz
# !pip install sweetviz

# %%
import sweetviz as sv
# genrate the report 
report = sv.analyze(df)
# Out:
#                                              |          | [  0%]   00:00 -> (? left)

# %%
# aslo save the report 
report.show_html("Pharmacy_Sweetviz_Report.html")
# Out:
# Report Pharmacy_Sweetviz_Report.html was generated! NOTEBOOK/COLAB USERS: the web browser MAY not pop up, regardless, the report IS saved in your notebook/colab files.
